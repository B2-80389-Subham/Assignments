# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("crime_data.csv")

# %%
df.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
df.isna().sum()
# Out:
# Unnamed: 0    0
# Murder        0
# Assault       0
# UrbanPop      0
# Rape          0
# dtype: int64

# %%
df.head()
# Out:
#    Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0     Alabama    13.2      236        58  21.2
# 1      Alaska    10.0      263        48  44.5
# 2     Arizona     8.1      294        80  31.0
# 3    Arkansas     8.8      190        50  19.5
# 4  California     9.0      276        91  40.6

# %%
df.drop('Unnamed: 0', axis=1 , inplace=True)

# %%
df.head()
# Out:
#    Murder  Assault  UrbanPop  Rape
# 0    13.2      236        58  21.2
# 1    10.0      263        48  44.5
# 2     8.1      294        80  31.0
# 3     8.8      190        50  19.5
# 4     9.0      276        91  40.6

# %%
def build_std_scaler(df):
    from sklearn.preprocessing import StandardScaler
    scaler = StandardScaler()
    scaled = scaler.fit_transform(df)
    return scaled

# %%
columns = np.array(['Murder','Assault','UrbanPop','Rape'])

df1= pd.DataFrame(df, columns=columns)

# %%
df1
# Out:
#     Murder  Assault  UrbanPop  Rape
# 0     13.2      236        58  21.2
# 1     10.0      263        48  44.5
# 2      8.1      294        80  31.0
# 3      8.8      190        50  19.5
# 4      9.0      276        91  40.6
# 5      7.9      204        78  38.7
# 6      3.3      110        77  11.1
# 7      5.9      238        72  15.8
# 8     15.4      335        80  31.9
# 9     17.4      211        60  25.8
# 10     5.3       46        83  20.2
# 11     2.6      120        54  14.2
# 12    10.4      249        83  24.0
# 13     7.2      113        65  21.0
# 14     2.2       56        57  11.3
# 15     6.0      115        66  18.0
# 16     9.7      109        52  16.3
# 17    15.4      249        66  22.2
# 18     2.1       83        51   7.8
# 19    11.3      300        67  27.8
# 20     4.4      149        85  16.3
# 21    12.1      255        74  35.1
# 22     2.7       72        66  14.9
# 23    16.1      259        44  17.1
# 24     9.0      178        70  28.2
# ...

# %% [markdown]
# # DATA 2

# %%
df2 = pd.read_csv("EastWest .csv")

# %%
df2.head(3)
# Out:
#    ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    1    28143           0          1          1          1          174
# 1    2    19244           0          1          1          1          215
# 2    3    41354           0          1          1          1         4123
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0

# %%
df2.isna().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df2 = build_std_scaler(df2)

# %%
df2
# Out:
# array([[-1.73512503e+00, -4.51140783e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-1.73426342e+00, -5.39456874e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-1.73340181e+00, -3.20031232e-01, -1.86298687e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [ 1.72682006e+00, -4.29480975e-05, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [ 1.72768167e+00, -1.85606976e-01, -1.86298687e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [ 1.72854328e+00, -7.00507951e-01, -1.86298687e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
df2 = pd.DataFrame(df2)

# %%
df2
# Out:
#             0         1         2         3         4         5         6   \
# 0    -1.735125 -0.451141 -0.186299 -0.769578 -0.098242 -0.062767 -0.702786
# 1    -1.734263 -0.539457 -0.186299 -0.769578 -0.098242 -0.062767 -0.701088
# 2    -1.733402 -0.320031 -0.186299 -0.769578 -0.098242 -0.062767 -0.539253
# 3    -1.732540 -0.583799 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 4    -1.731679  0.239678 -0.186299  1.409471 -0.098242 -0.062767  1.083121
# ...        ...       ...       ...       ...       ...       ...       ...
# 3994  1.725097 -0.547079 -0.186299 -0.769578 -0.098242 -0.062767 -0.356960
# 3995  1.725958 -0.091465 -0.186299 -0.769578 -0.098242 -0.062767 -0.669367
# 3996  1.726820 -0.000043 -0.186299  0.683121 -0.098242 -0.062767  0.343804
# 3997  1.727682 -0.185607 -0.186299 -0.769578 -0.098242 -0.062767 -0.689286
# 3998  1.728543 -0.700508 -0.186299 -0.769578 -0.098242 -0.062767 -0.709992
#
#             7         8         9         10        11
# ...

# %% [markdown]
# # data3

# %%
df3 =pd.read_csv("framingham.csv")

# %%
df3.isna().sum()
# Out:
# male                 0
# age                  0
# education          105
# currentSmoker        0
# cigsPerDay          29
# BPMeds              53
# prevalentStroke      0
# prevalentHyp         0
# diabetes             0
# totChol             50
# sysBP                0
# diaBP                0
# BMI                 19
# heartRate            1
# glucose            388
# TenYearCHD           0
# dtype: int64

# %%
df3.dropna(inplace=True)

# %%
df3 = build_std_scaler(df3)

# %%
df3 = pd.DataFrame(df3)

# %%
df3
# Out:
#             0         1         2         3         4         5         6   \
# 0     1.119755 -1.232580  1.975209 -0.978364 -0.757169 -0.176901 -0.075987
# 1    -0.893053 -0.414905  0.019249 -0.978364 -0.757169 -0.176901 -0.075987
# 2     1.119755 -0.181283 -0.958730  1.022114  0.920689 -0.176901 -0.075987
# 3    -0.893053  1.337256  0.997229  1.022114  1.759618 -0.176901 -0.075987
# 4    -0.893053 -0.414905  0.997229  1.022114  1.172368 -0.176901 -0.075987
# ...        ...       ...       ...       ...       ...       ...       ...
# 3653  1.119755  0.052338 -0.958730  1.022114 -0.673276 -0.176901 -0.075987
# 3654  1.119755  0.169149  0.997229  1.022114  2.850225 -0.176901 -0.075987
# 3655 -0.893053  0.285960  0.019249 -0.978364 -0.757169 -0.176901 -0.075987
# 3656  1.119755 -1.115769  0.997229 -0.978364 -0.757169 -0.176901 -0.075987
# 3657 -0.893053 -1.232580  0.997229  1.022114  1.759618 -0.176901 -0.075987
#
# ...

# %% [markdown]
# # data4

# %%
df4 = pd.read_csv("Grocery.csv")

# %%
df4.isna().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicassen          0
# dtype: int64

# %%
df4 = build_std_scaler(df4)

# %%
df4 = pd.DataFrame(df4)

# %%
df4
# Out:
#             0         1         2         3         4         5         6  \
# 0    1.448652  0.590668  0.052933  0.523568 -0.041115 -0.589367 -0.043569
# 1    1.448652  0.590668 -0.391302  0.544458  0.170318 -0.270136  0.086407
# 2    1.448652  0.590668 -0.447029  0.408538 -0.028157 -0.137536  0.133232
# 3   -0.690297  0.590668  0.100111 -0.624020 -0.392977  0.687144 -0.498588
# 4    1.448652  0.590668  0.840239 -0.052396 -0.079356  0.173859 -0.231918
# ..        ...       ...       ...       ...       ...       ...       ...
# 435 -0.690297  0.590668  1.401312  0.848446  0.850760  2.075222 -0.566831
# 436 -0.690297  0.590668  2.155293 -0.592142 -0.757165  0.296561 -0.585519
# 437  1.448652  0.590668  0.200326  1.314671  2.348386 -0.543380  2.511218
# 438 -0.690297  0.590668 -0.135384 -0.517536 -0.602514 -0.419441 -0.569770
# 439 -0.690297  0.590668 -0.729307 -0.555924 -0.573227 -0.620094 -0.504888
#
#             7
# 0   -0.066339
# 1    0.089151
# 2    2.243293
# 3    0.093411
# ...

# %% [markdown]
# # data5

# %%
df5 = pd.read_csv("Universities.csv")

# %%
df5.isna().sum()
# Out:
# Univ        0
# SAT         0
# Top10       0
# Accept      0
# SFRatio     0
# Expenses    0
# GradRate    0
# dtype: int64

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Univ      25 non-null     object
#  1   SAT       25 non-null     int64
#  2   Top10     25 non-null     int64
#  3   Accept    25 non-null     int64
#  4   SFRatio   25 non-null     int64
#  5   Expenses  25 non-null     int64
#  6   GradRate  25 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 1.5+ KB

# %%
df5.drop(['Univ'], axis=1, inplace=True)

# %%
df5 = build_std_scaler(df5)

# %%
df5 = pd.DataFrame(df5)

# %%
df5
# Out:
#            0         1         2         3         4         5
# 0   0.410284  0.657519 -0.889867  0.070260 -0.331413  0.820303
# 1   1.399259  1.235212 -0.734657 -1.686251  2.560381 -0.644524
# 2  -0.060657 -0.760454  1.024382 -0.933460 -0.167121 -1.658634
# 3   0.410284 -0.025208 -0.786394 -0.180670  0.291649  0.144229
# 4   0.127719  0.342414 -0.320766  0.070260 -0.390846  0.369587
# 5   0.692848  0.657519 -0.838130 -0.682530  0.337780  0.932982
# 6   0.457378  0.710037 -0.475975 -0.180670  0.296955  0.932982
# 7  -0.107751 -0.130243 -0.786394 -0.180670 -0.513817  0.594945
# 8   1.257977  0.762555 -1.303758 -0.431600  0.858743  1.158339
# 9   0.363190 -0.077726  0.248335 -1.435321  2.214818  0.031550
# 10  1.069601  0.920107 -0.475975 -0.682530  0.529383  0.482266
# 11 -0.060657  0.447449 -0.010347 -0.431600  0.046981  0.256908
# 12 -0.107751  0.237379  0.144862  0.070260 -0.867871  0.820303
# 13 -1.746625 -2.020875  0.765699  1.324911 -1.217184 -0.757202
# ...
