# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("IceCreamData.csv")

# %%
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
X = df.drop(["Revenue"], axis =1)
Y = df['Revenue']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y, train_size = 0.7 ,random_state=12345)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y)

# %%
model.predict(X)
plt.scatter(X,Y)
plt.plot(X,model.predict(X), color ="red",label= "regression line"  )

# %% [markdown]
# # polynomial regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=2)
x_new_train = poly.fit_transform(x_train)
x_new_test = poly.transform(x_test)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x_new_train, y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test, model.predict(x_new_test) ,color = "red")

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
r2 = r2_score(y_test,model.predict(x_new_test) )
mae = mean_absolute_error(y_test,model.predict(x_new_test))
mse = mean_squared_error(y_test,model.predict(x_new_test))
rmse = np.sqrt(mse)

# %%
print(f"mae = {mae}")
print(f"mse = {mse}")
print(f"rmse = {rmse}")
print(f"r2 = {r2}")
# Out:
# mae = 20.202626755588444
# mse = 654.1394784986315
# rmse = 25.576150580152433
# r2 = 0.9784316281262379
