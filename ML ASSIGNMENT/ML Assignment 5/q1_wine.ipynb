# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
wine_df = pd.read_csv('wine_std.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 wine_df = pd.read_csv('wine_std.csv')
#
# NameError: name 'pd' is not defined

# %%
wine_df.head()
# Out:
#    Unnamed: 0      Type   Alcohol     Malic       Ash  Alcalinity  Magnesium  \
# 0           0 -1.213944  1.518613 -0.562250  0.232053   -1.169593   1.913905
# 1           1 -1.213944  0.246290 -0.499413 -0.827996   -2.490847   0.018145
# 2           2 -1.213944  0.196879  0.021231  1.109334   -0.268738   0.088358
# 3           3 -1.213944  1.691550 -0.346811  0.487926   -0.809251   0.930918
# 4           4 -1.213944  0.295700  0.227694  1.840403    0.451946   1.281985
#
#     Phenols  Flavanoids  Nonflavanoids  Proanthocyanins     Color       Hue  \
# 0  0.808997    1.034819      -0.659563         1.224884  0.251717  0.362177
# 1  0.568648    0.733629      -0.820719        -0.544721 -0.293321  0.406051
# 2  0.808997    1.215533      -0.498407         2.135968  0.269020  0.318304
# 3  2.491446    1.466525      -0.981875         1.032155  1.186068 -0.427544
# 4  0.808997    0.663351       0.226796         0.401404 -0.319276  0.362177
#
#    Dilution   Proline
# 0  1.847920  1.013009
# ...

# %%
wine_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178 entries, 0 to 177
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       178 non-null    int64
#  1   Type             178 non-null    float64
#  2   Alcohol          178 non-null    float64
#  3   Malic            178 non-null    float64
#  4   Ash              178 non-null    float64
#  5   Alcalinity       178 non-null    float64
#  6   Magnesium        178 non-null    float64
#  7   Phenols          178 non-null    float64
#  8   Flavanoids       178 non-null    float64
#  9   Nonflavanoids    178 non-null    float64
#  10  Proanthocyanins  178 non-null    float64
#  11  Color            178 non-null    float64
#  12  Hue              178 non-null    float64
#  13  Dilution         178 non-null    float64
#  14  Proline          178 non-null    float64
# dtypes: float64(14), int64(1)
# memory usage: 21.0 KB

# %%
wine_df.describe()
# Out:
#        Unnamed: 0        Type       Alcohol         Malic           Ash  \
# count  178.000000  178.000000  1.780000e+02  1.780000e+02  1.780000e+02
# mean    88.500000    0.000000 -8.382808e-16 -7.983626e-17 -8.170742e-16
# std     51.528309    1.002821  1.002821e+00  1.002821e+00  1.002821e+00
# min      0.000000   -1.213944 -2.434235e+00 -1.432983e+00 -3.679162e+00
# 25%     44.250000   -1.213944 -7.882448e-01 -6.587486e-01 -5.721225e-01
# 50%     88.500000    0.079960  6.099988e-02 -4.231120e-01 -2.382132e-02
# 75%    132.750000    1.373864  8.361286e-01  6.697929e-01  6.981085e-01
# max    177.000000    1.373864  2.259772e+00  3.109192e+00  3.156325e+00
#
#          Alcalinity     Magnesium       Phenols    Flavanoids  Nonflavanoids  \
# count  1.780000e+02  1.780000e+02  1.780000e+02  1.780000e+02   1.780000e+02
# mean  -3.991813e-17 -3.991813e-17 -3.991813e-17 -4.390994e-16   3.592632e-16
# std    1.002821e+00  1.002821e+00  1.002821e+00  1.002821e+00   1.002821e+00
# ...

# %%
wine_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
from sklearn.decomposition import PCA

# %%
wine_df.columns
# Out:
# Index(['Type', 'Alcohol', 'Malic', 'Ash', 'Alcalinity', 'Magnesium', 'Phenols',
#        'Flavanoids', 'Nonflavanoids', 'Proanthocyanins', 'Color', 'Hue',
#        'Dilution', 'Proline'],
#       dtype='object')

# %%
wine_df.corr()
# Out:
#                      Type   Alcohol     Malic       Ash  Alcalinity  \
# Type             1.000000 -0.328222  0.437776 -0.049643    0.517859
# Alcohol         -0.328222  1.000000  0.094397  0.211545   -0.310235
# Malic            0.437776  0.094397  1.000000  0.164045    0.288500
# Ash             -0.049643  0.211545  0.164045  1.000000    0.443367
# Alcalinity       0.517859 -0.310235  0.288500  0.443367    1.000000
# Magnesium       -0.209179  0.270798 -0.054575  0.286587   -0.083333
# Phenols         -0.719163  0.289101 -0.335167  0.128980   -0.321113
# Flavanoids      -0.847498  0.236815 -0.411007  0.115077   -0.351370
# Nonflavanoids    0.489109 -0.155929  0.292977  0.186230    0.361922
# Proanthocyanins -0.499130  0.136698 -0.220746  0.009652   -0.197327
# Color            0.265668  0.546364  0.248985  0.258887    0.018732
# Hue             -0.617369 -0.071747 -0.561296 -0.074667   -0.273955
# Dilution        -0.788230  0.072343 -0.368710  0.003911   -0.276769
# ...

# %%
pca = PCA(n_components=3)

wine_reduced = pca.fit_transform(wine_df)

# %%
wine_reduced
# Out:
# array([[-3.52293390e+00, -1.45309844e+00, -1.64795488e-01],
#        [-2.52885806e+00,  3.30019252e-01, -2.02670665e+00],
#        [-2.78502898e+00, -1.03693595e+00,  9.83237703e-01],
#        [-3.92258841e+00, -2.76821026e+00, -1.74968168e-01],
#        [-1.40751111e+00, -8.67773087e-01,  2.02582949e+00],
#        [-3.28812981e+00, -2.13017513e+00, -6.28992339e-01],
#        [-2.75057754e+00, -1.17916999e+00, -9.77337471e-01],
#        [-2.39286652e+00, -1.61128232e+00,  1.45729462e-01],
#        [-2.79525633e+00, -9.23179517e-01, -1.77092548e+00],
#        [-3.00559666e+00, -7.96284169e-01, -9.83741629e-01],
#        [-3.67868855e+00, -1.31252342e+00, -4.21854170e-01],
#        [-2.10963477e+00, -6.12981986e-01, -1.19156995e+00],
#        [-2.43845636e+00, -6.78523310e-01, -8.65513701e-01],
#        [-3.67349453e+00, -1.14012136e+00, -1.20376870e+00],
#        [-4.44157575e+00, -2.11031917e+00, -1.26245041e+00],
#        [-2.60892387e+00, -1.66641801e+00,  2.17632760e-01],
# ...
