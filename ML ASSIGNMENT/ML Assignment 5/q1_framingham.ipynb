# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
framingham_df = pd.read_csv('Framingham_std.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 framingham_df = pd.read_csv('Framingham_std.csv')
#
# NameError: name 'pd' is not defined

# %%
framingham_df.head()
# Out:
#    Unnamed: 0      male       age  education  currentSmoker  cigsPerDay  \
# 0           0  1.119755 -1.232580   1.975209      -0.978364   -0.757169
# 1           1 -0.893053 -0.414905   0.019249      -0.978364   -0.757169
# 2           2  1.119755 -0.181283  -0.958730       1.022114    0.920689
# 3           3 -0.893053  1.337256   0.997229       1.022114    1.759618
# 4           4 -0.893053 -0.414905   0.997229       1.022114    1.172368
#
#      BPMeds  prevalentStroke  prevalentHyp  diabetes   totChol     sysBP  \
# 0 -0.176901        -0.075987     -0.672860 -0.166784 -0.949108 -1.194111
# 1 -0.176901        -0.075987     -0.672860 -0.166784  0.298294 -0.514881
# 2 -0.176901        -0.075987     -0.672860 -0.166784  0.184894 -0.220548
# 3 -0.176901        -0.075987      1.486194 -0.166784 -0.268707  0.798296
# 4 -0.176901        -0.075987     -0.672860 -0.166784  1.092095 -0.107344
#
#       diaBP       BMI  heartRate   glucose
# 0 -1.078881  0.292050   0.356370 -0.203044
# ...

# %%
framingham_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3658 entries, 0 to 3657
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       3658 non-null   int64
#  1   male             3658 non-null   float64
#  2   age              3658 non-null   float64
#  3   education        3658 non-null   float64
#  4   currentSmoker    3658 non-null   float64
#  5   cigsPerDay       3658 non-null   float64
#  6   BPMeds           3658 non-null   float64
#  7   prevalentStroke  3658 non-null   float64
#  8   prevalentHyp     3658 non-null   float64
#  9   diabetes         3658 non-null   float64
#  10  totChol          3658 non-null   float64
#  11  sysBP            3658 non-null   float64
#  12  diaBP            3658 non-null   float64
#  13  BMI              3658 non-null   float64
#  14  heartRate        3658 non-null   float64
#  15  glucose          3658 non-null   float64
# ...

# %%
framingham_df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
framingham_df.describe()
# Out:
#                male           age     education  currentSmoker    cigsPerDay  \
# count  3.658000e+03  3.658000e+03  3.658000e+03   3.658000e+03  3.658000e+03
# mean   1.573372e-16 -2.330922e-16  9.712175e-19  -4.273357e-17  2.622287e-17
# std    1.000137e+00  1.000137e+00  1.000137e+00   1.000137e+00  1.000137e+00
# min   -8.930526e-01 -2.050255e+00 -9.587302e-01  -9.783641e-01 -7.571689e-01
# 25%   -8.930526e-01 -8.821476e-01 -9.587302e-01  -9.783641e-01 -7.571689e-01
# 50%   -8.930526e-01 -6.447261e-02  1.924946e-02  -9.783641e-01 -7.571689e-01
# 75%    1.119755e+00  7.532023e-01  9.972291e-01   1.022114e+00  9.206890e-01
# max    1.119755e+00  2.388552e+00  1.975209e+00   1.022114e+00  5.115334e+00
#
#              BPMeds  prevalentStroke  prevalentHyp      diabetes  \
# count  3.658000e+03     3.658000e+03  3.658000e+03  3.658000e+03
# mean   6.992766e-17    -5.827305e-18 -2.719409e-17  1.942435e-17
# std    1.000137e+00     1.000137e+00  1.000137e+00  1.000137e+00
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=4)

framingham_reduced = pca.fit_transform(framingham_df)

# %%
framingham_reduced
# Out:
# array([[-1.79611631, -1.01468796,  0.0311208 ,  0.57987424],
#        [ 0.01183365, -1.28529786, -0.14690311, -1.48230826],
#        [-1.01400499,  1.42343418, -0.13568633,  0.34204866],
#        ...,
#        [ 0.1681845 , -1.52561995,  0.62583935, -0.95054185],
#        [ 0.74166253, -0.1407305 , -0.93974478,  1.28484825],
#        [-1.58884896,  1.44864884,  0.00923559, -1.3998523 ]])
